# %% [markdown]
# # Exoplanet Classification Data Prep

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

pd.set_option('display.max_row', 100)
pd.set_option('display.max_columns', 75)

# %% [markdown]
# ### Read Data

# %%
cumulativeOOI = pd.read_csv('./cumulativeooi.csv')

# %%
cumulativeOOI.head(5)
# Out:
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_vet_stat  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED       Active
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED       Active
# 2      3  10811496  K00753.01           NaN       CANDIDATE       Active
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE       Active
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED       Active
#
#   koi_vet_date koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 0    8/16/2018        CANDIDATE      1.000              0              0
# 1    8/16/2018        CANDIDATE      0.969              0              0
# 2    8/16/2018        CANDIDATE      0.000              0              0
# 3    8/16/2018   FALSE POSITIVE      0.000              0              1
# 4    8/16/2018        CANDIDATE      1.000              0              0
#
#    koi_fpflag_co  koi_fpflag_ec        koi_disp_prov  \
# 0              0              0  q1_q17_dr25_sup_koi
# 1              0              0  q1_q17_dr25_sup_koi
# 2              0              0  q1_q17_dr25_sup_koi
# 3              0              0  q1_q17_dr25_sup_koi
# 4              0              0  q1_q17_dr25_sup_koi
#
#                                         koi_comment  koi_period  koi_time0bk  \
# 0                                        NO_COMMENT    9.488036   170.538750
# 1                                        NO_COMMENT   54.418383   162.513840
# 2                                     DEEP_V_SHAPED   19.899140   175.850252
# 3  MOD_ODDEVEN_DV---MOD_ODDEVEN_ALT---DEEP_V_SHAPED    1.736952   170.307565
# 4                                        NO_COMMENT    2.525592   171.595550
#
#      koi_time0  koi_eccen  koi_longp  koi_impact  koi_duration  koi_ingress  \
# 0  2455003.539        0.0        NaN       0.146       2.95750          NaN
# 1  2454995.514        0.0        NaN       0.586       4.50700          NaN
# 2  2455008.850        0.0        NaN       0.969       1.78220          NaN
# 3  2455003.308        0.0        NaN       1.276       2.40641          NaN
# 4  2455004.596        0.0        NaN       0.701       1.65450          NaN
#
#    koi_depth   koi_ror  koi_srho koi_fittype  koi_prad  koi_sma  koi_incl  \
# 0      616.0  0.022344   3.20796     LS+MCMC      2.26   0.0853     89.66
# 1      875.0  0.027954   3.02368     LS+MCMC      2.83   0.2734     89.57
# 2    10800.0  0.154046   7.29555     LS+MCMC     14.60   0.1419     88.96
# 3     8080.0  0.387394   0.22080     LS+MCMC     33.46   0.0267     67.09
# 4      603.0  0.024064   1.98635     LS+MCMC      2.75   0.0374     85.41
#
#    koi_teq  koi_insol  koi_dor                   koi_limbdark_mod  \
# 0    793.0      93.59   24.810  Claret (2011 A&A 529 75) ATLAS LS
# 1    443.0       9.11   77.900  Claret (2011 A&A 529 75) ATLAS LS
# 2    638.0      39.30   53.500  Claret (2011 A&A 529 75) ATLAS LS
# 3   1395.0     891.96    3.278  Claret (2011 A&A 529 75) ATLAS LS
# 4   1406.0     926.16    8.750  Claret (2011 A&A 529 75) ATLAS LS
#
#    koi_ldm_coeff4  koi_ldm_coeff3  koi_ldm_coeff2       ...        \
# 0             0.0             0.0          0.2291       ...
# 1             0.0             0.0          0.2291       ...
# 2             0.0             0.0          0.2711       ...
# 3             0.0             0.0          0.2865       ...
# 4             0.0             0.0          0.2844       ...
#
#    koi_quarters koi_bin_oedp_sig                       koi_trans_mod  \
# 0  1.111110e+31           0.6864  Mandel and Agol (2002 ApJ 580 171)
# 1  1.111110e+31           0.0023  Mandel and Agol (2002 ApJ 580 171)
# 2  1.111110e+31           0.6624  Mandel and Agol (2002 ApJ 580 171)
# 3  1.111110e+31           0.0000  Mandel and Agol (2002 ApJ 580 171)
# 4  1.111110e+30           0.3090  Mandel and Agol (2002 ApJ 580 171)
#
#    koi_model_dof  koi_model_chisq  \
# 0            NaN              NaN
# 1            NaN              NaN
# 2            NaN              NaN
# 3            NaN              NaN
# 4            NaN              NaN
#
#                                     koi_datalink_dvr  \
# 0  010/010797/010797460/dv/kplr010797460-20160209...
# 1  010/010797/010797460/dv/kplr010797460-20160209...
# 2  010/010811/010811496/dv/kplr010811496-20160209...
# 3  010/010848/010848459/dv/kplr010848459-20160209...
# 4  010/010854/010854555/dv/kplr010854555-20160209...
#
#                                     koi_datalink_dvs  koi_steff koi_slogg  \
# 0  010/010797/010797460/dv/kplr010797460-001-2016...     5455.0     4.467
# 1  010/010797/010797460/dv/kplr010797460-002-2016...     5455.0     4.467
# 2  010/010811/010811496/dv/kplr010811496-001-2016...     5853.0     4.544
# 3  010/010848/010848459/dv/kplr010848459-001-2016...     5805.0     4.564
# 4  010/010854/010854555/dv/kplr010854555-001-2016...     6031.0     4.438
#
#    koi_smet  koi_srad koi_smass  koi_sage         koi_sparprov         ra  \
# 0      0.14     0.927     0.919       NaN  q1_q17_dr25_stellar  291.93423
# 1      0.14     0.927     0.919       NaN  q1_q17_dr25_stellar  291.93423
# 2     -0.18     0.868     0.961       NaN  q1_q17_dr25_stellar  297.00482
# 3     -0.52     0.791     0.836       NaN  q1_q17_dr25_stellar  285.53461
# 4      0.07     1.046     1.095       NaN  q1_q17_dr25_stellar  288.75488
#
#          dec  koi_kepmag  koi_gmag  koi_rmag  koi_imag  koi_zmag  koi_jmag  \
# 0  48.141651      15.347    15.890    15.270    15.114    15.006    14.082
# 1  48.141651      15.347    15.890    15.270    15.114    15.006    14.082
# 2  48.134129      15.436    15.943    15.390    15.220    15.166    14.254
# 3  48.285210      15.597    16.100    15.554    15.382    15.266    14.326
# 4  48.226200      15.509    16.015    15.468    15.292    15.241    14.366
#
#   koi_hmag  koi_kmag  koi_fwm_stat_sig  koi_fwm_sra  koi_fwm_sdec  \
# 0   13.751    13.648             0.002    19.462294      48.14191
# 1   13.751    13.648             0.003    19.462265      48.14199
# 2   13.900    13.826             0.278    19.800321      48.13412
# 3   13.911    13.809             0.000    19.035638      48.28521
# 4   14.064    13.952             0.733    19.250326      48.22626
#
#    koi_fwm_srao  koi_fwm_sdeco  koi_fwm_prao  koi_fwm_pdeco  koi_dicco_mra  \
# 0         0.430          0.940      -0.00020       -0.00055         -0.010
# 1        -0.630          1.230       0.00066       -0.00105          0.390
# 2        -0.021         -0.038       0.00070        0.00060         -0.025
# 3        -0.111          0.002       0.00302       -0.00142         -0.249
# 4        -0.010          0.230       0.00008       -0.00007          0.030
#
#    koi_dicco_mdec  koi_dicco_msky  koi_dikco_mra  koi_dikco_mdec  \
# 0           0.200           0.200          0.080           0.310
# 1           0.000           0.390          0.490           0.120
# 2          -0.034           0.042          0.002          -0.027
# 3           0.147           0.289         -0.257           0.099
# 4          -0.090           0.100          0.070           0.020
#
#    koi_dikco_msky
# 0           0.320
# 1           0.500
# 2           0.027
# 3           0.276
# 4           0.070
#
# [5 rows x 83 columns]

# %%
cumulativeOOI.describe()
# Out:
#              rowid         kepid    koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# count  9564.000000  9.564000e+03  8054.000000    9564.000000    9564.000000
# mean   4782.500000  7.690628e+06     0.480829       0.208595       0.232748
# std    2761.033321  2.653459e+06     0.476928       4.767290       0.422605
# min       1.000000  7.574500e+05     0.000000       0.000000       0.000000
# 25%    2391.750000  5.556034e+06     0.000000       0.000000       0.000000
# 50%    4782.500000  7.906892e+06     0.334000       0.000000       0.000000
# 75%    7173.250000  9.873066e+06     0.998000       0.000000       0.000000
# max    9564.000000  1.293514e+07     1.000000     465.000000       1.000000
#
#        koi_fpflag_co  koi_fpflag_ec     koi_period  koi_time0bk     koi_time0  \
# count    9564.000000    9564.000000    9564.000000  9564.000000  9.564000e+03
# mean        0.197512       0.120033      75.671358   166.183251  2.454999e+06
# std         0.398142       0.325018    1334.744046    67.918960  6.791896e+01
# min         0.000000       0.000000       0.241843   120.515914  2.454954e+06
# 25%         0.000000       0.000000       2.733684   132.761718  2.454966e+06
# 50%         0.000000       0.000000       9.752831   137.224595  2.454970e+06
# 75%         0.000000       0.000000      40.715178   170.694603  2.455004e+06
# max         1.000000       1.000000  129995.778400  1472.522306  2.456306e+06
#
#        koi_eccen  koi_longp   koi_impact  koi_duration  koi_ingress  \
# count     9201.0        0.0  9201.000000   9564.000000          0.0
# mean         0.0        NaN     0.735105      5.621606          NaN
# std          0.0        NaN     3.348832      6.471554          NaN
# min          0.0        NaN     0.000000      0.052000          NaN
# 25%          0.0        NaN     0.197000      2.437750          NaN
# 50%          0.0        NaN     0.537000      3.792600          NaN
# 75%          0.0        NaN     0.889000      6.276500          NaN
# max          0.0        NaN   100.806000    138.540000          NaN
#
#           koi_depth      koi_ror     koi_srho       koi_prad      koi_sma  \
# count  9.201000e+03  9201.000000  9243.000000    9201.000000  9201.000000
# mean   2.379245e+04     0.283646     9.164414     102.891778     0.223989
# std    8.224316e+04     3.306558    53.807967    3077.639126     0.566359
# min    0.000000e+00     0.001289     0.000040       0.080000     0.005900
# 25%    1.600000e+02     0.012341     0.229250       1.400000     0.037700
# 50%    4.210000e+02     0.021076     0.956720       2.390000     0.085100
# 75%    1.470000e+03     0.095348     2.897175      14.930000     0.214400
# max    1.540000e+06    99.870651   980.854190  200346.000000    44.989200
#
#           koi_incl       koi_teq     koi_insol       koi_dor  koi_ldm_coeff4  \
# count  9200.000000   9201.000000  9.243000e+03   9201.000000          9201.0
# mean     82.469147   1085.385828  7.745737e+03     76.736333             0.0
# std      15.223627    856.351161  1.592047e+05    845.274598             0.0
# min       2.290000     25.000000  0.000000e+00      0.373000             0.0
# 25%      83.920000    539.000000  2.015000e+01      5.358000             0.0
# 50%      88.500000    878.000000  1.416000e+02     15.460000             0.0
# 75%      89.770000   1379.000000  8.702900e+02     45.370000             0.0
# max      90.000000  14667.000000  1.094755e+07  79614.000000             0.0
#
#        koi_ldm_coeff3  koi_ldm_coeff2  koi_ldm_coeff1  koi_max_sngle_ev  \
# count          9201.0     9201.000000     9201.000000       8422.000000
# mean              0.0        0.254439        0.407617        176.846052
# std               0.0        0.064806        0.106076        770.902357
# min               0.0       -0.120600        0.125400          2.417437
# 25%               0.0        0.228600        0.326800          3.997856
# 50%               0.0        0.271100        0.392000          5.589751
# 75%               0.0        0.299800        0.464100         16.947631
# max               0.0        0.482200        0.948600      22982.162000
#
#        koi_max_mult_ev  koi_model_snr    koi_count  koi_num_transits  \
# count      8422.000000    9201.000000  9564.000000       8422.000000
# mean       1025.664672     259.895001     1.406315        385.006768
# std        4154.121620     795.806615     0.873289        545.756200
# min           7.105086       0.000000     1.000000          0.000000
# 25%          10.733030      12.000000     1.000000         41.000000
# 50%          19.254412      23.000000     1.000000        143.000000
# 75%          71.998003      78.000000     1.000000        469.000000
# max      120049.680000    9054.700000     7.000000       2664.000000
#
#        koi_tce_plnt_num  koi_quarters  koi_bin_oedp_sig  koi_model_dof  \
# count       9218.000000  8.422000e+03       8054.000000            0.0
# mean           1.243654  9.151387e+30          0.409500            NaN
# std            0.664573  4.153749e+30          0.500793            NaN
# min            1.000000  1.000000e+15         -1.000000            NaN
# 25%            1.000000  1.111100e+31          0.134650            NaN
# 50%            1.000000  1.111110e+31          0.486600            NaN
# 75%            1.000000  1.111110e+31          0.810375            NaN
# max            8.000000  1.111110e+31          1.000000            NaN
#
#        koi_model_chisq     koi_steff    koi_slogg     koi_smet     koi_srad  \
# count              0.0   9201.000000  9201.000000  9178.000000  9201.000000
# mean               NaN   5706.823280     4.310157    -0.124431     1.728712
# std                NaN    796.857947     0.432606     0.282111     6.127185
# min                NaN   2661.000000     0.047000    -2.500000     0.109000
# 25%                NaN   5310.000000     4.218000    -0.260000     0.829000
# 50%                NaN   5767.000000     4.438000    -0.100000     1.000000
# 75%                NaN   6112.000000     4.543000     0.070000     1.345000
# max                NaN  15896.000000     5.364000     0.560000   229.908000
#
#          koi_smass  koi_sage           ra          dec   koi_kepmag  \
# count  9201.000000       0.0  9564.000000  9564.000000  9563.000000
# mean      1.023706       NaN   292.060163    43.810433    14.264606
# std       0.349447       NaN     4.766657     3.601243     1.385448
# min       0.000000       NaN   279.852720    36.577381     6.966000
# 25%       0.845000       NaN   288.660770    40.777173    13.440000
# 50%       0.974000       NaN   292.261125    43.677504    14.520000
# 75%       1.101000       NaN   295.859160    46.714611    15.322000
# max       3.735000       NaN   301.720760    52.336010    20.003000
#
#           koi_gmag     koi_rmag     koi_imag     koi_zmag     koi_jmag  \
# count  9523.000000  9555.000000  9410.000000  8951.000000  9539.000000
# mean     14.830501    14.221565    14.075138    13.991724    12.993311
# std       1.501885     1.383713     1.292573     1.230351     1.291912
# min       7.225000     7.101000     7.627000     6.702000     4.097000
# 25%      13.896500    13.393000    13.294000    13.276000    12.253000
# 50%      15.064000    14.471000    14.317500    14.254000    13.236000
# 75%      15.935500    15.275000    15.063000    14.943000    13.968000
# max      21.150000    19.960000    19.900000    17.403000    17.372000
#
#           koi_hmag    koi_kmag  koi_fwm_stat_sig  koi_fwm_sra  koi_fwm_sdec  \
# count  9539.000000  9539.00000       8488.000000  9058.000000   9058.000000
# mean     12.620604    12.54341          0.150994    19.471356     43.829239
# std       1.267215     1.26818          0.252648     0.319158      3.599553
# min       3.014000     2.31100          0.000000    18.657036     36.576888
# 25%      11.914500    11.84300          0.000000    19.243889     40.798688
# 50%      12.834000    12.74400          0.006000    19.484983     43.694115
# 75%      13.551000    13.48450          0.196250    19.726785     46.720630
# max      17.615000    17.03800          1.000000    20.114785     52.338190
#
#        koi_fwm_srao  koi_fwm_sdeco  koi_fwm_prao  koi_fwm_pdeco  \
# count   9109.000000    9109.000000   8734.000000    8747.000000
# mean      -0.316136      -0.165817     -0.000097      -0.000714
# std       20.254777      20.534655      0.058225       0.092987
# min     -742.430000    -417.900000     -4.000000      -6.000000
# 25%       -0.600000      -0.680000     -0.000210      -0.000220
# 50%       -0.000500      -0.034000      0.000000       0.000000
# 75%        0.570000       0.500000      0.000240       0.000240
# max      549.500000     712.500000      1.190000       5.000000
#
#        koi_dicco_mra  koi_dicco_mdec  koi_dicco_msky  koi_dikco_mra  \
# count    8965.000000     8965.000000     8965.000000    8994.000000
# mean       -0.012281       -0.045420        1.866561      -0.024244
# std         2.406550        2.573558        2.988742       2.382286
# min       -25.100000      -75.900000        0.000000     -27.800000
# 25%        -0.320000       -0.387000        0.170000      -0.310000
# 50%         0.000000        0.000000        0.610000      -0.004000
# 75%         0.309000        0.300000        2.160000       0.290000
# max        45.680000       27.500000       88.600000      46.570000
#
#        koi_dikco_mdec  koi_dikco_msky
# count     8994.000000     8994.000000
# mean        -0.076749        1.812566
# std          2.553758        2.986376
# min        -76.600000        0.000000
# 25%         -0.390000        0.210000
# 50%         -0.017000        0.583000
# 75%          0.300000        1.970000
# max         34.000000       89.600000

# %%
cumulativeOOI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 83 columns):
# rowid                9564 non-null int64
# kepid                9564 non-null int64
# kepoi_name           9564 non-null object
# kepler_name          2299 non-null object
# koi_disposition      9564 non-null object
# koi_vet_stat         9564 non-null object
# koi_vet_date         9564 non-null object
# koi_pdisposition     9564 non-null object
# koi_score            8054 non-null float64
# koi_fpflag_nt        9564 non-null int64
# koi_fpflag_ss        9564 non-null int64
# koi_fpflag_co        9564 non-null int64
# koi_fpflag_ec        9564 non-null int64
# koi_disp_prov        9564 non-null object
# koi_comment          8355 non-null object
# koi_period           9564 non-null float64
# koi_time0bk          9564 non-null float64
# koi_time0            9564 non-null float64
# koi_eccen            9201 non-null float64
# koi_longp            0 non-null float64
# koi_impact           9201 non-null float64
# koi_duration         9564 non-null float64
# koi_ingress          0 non-null float64
# koi_depth            9201 non-null float64
# koi_ror              9201 non-null float64
# koi_srho             9243 non-null float64
# koi_fittype          9564 non-null object
# koi_prad             9201 non-null float64
# koi_sma              9201 non-null float64
# koi_incl             9200 non-null float64
# koi_teq              9201 non-null float64
# koi_insol            9243 non-null float64
# koi_dor              9201 non-null float64
# koi_limbdark_mod     9201 non-null object
# koi_ldm_coeff4       9201 non-null float64
# koi_ldm_coeff3       9201 non-null float64
# koi_ldm_coeff2       9201 non-null float64
# koi_ldm_coeff1       9201 non-null float64
# koi_parm_prov        9564 non-null object
# koi_max_sngle_ev     8422 non-null float64
# koi_max_mult_ev      8422 non-null float64
# koi_model_snr        9201 non-null float64
# koi_count            9564 non-null int64
# koi_num_transits     8422 non-null float64
# koi_tce_plnt_num     9218 non-null float64
# koi_tce_delivname    9218 non-null object
# koi_quarters         8422 non-null float64
# koi_bin_oedp_sig     8054 non-null float64
# koi_trans_mod        9201 non-null object
# koi_model_dof        0 non-null float64
# koi_model_chisq      0 non-null float64
# koi_datalink_dvr     9218 non-null object
# koi_datalink_dvs     9218 non-null object
# koi_steff            9201 non-null float64
# koi_slogg            9201 non-null float64
# koi_smet             9178 non-null float64
# koi_srad             9201 non-null float64
# koi_smass            9201 non-null float64
# koi_sage             0 non-null float64
# koi_sparprov         9201 non-null object
# ra                   9564 non-null float64
# dec                  9564 non-null float64
# koi_kepmag           9563 non-null float64
# koi_gmag             9523 non-null float64
# koi_rmag             9555 non-null float64
# koi_imag             9410 non-null float64
# koi_zmag             8951 non-null float64
# koi_jmag             9539 non-null float64
# koi_hmag             9539 non-null float64
# koi_kmag             9539 non-null float64
# koi_fwm_stat_sig     8488 non-null float64
# koi_fwm_sra          9058 non-null float64
# koi_fwm_sdec         9058 non-null float64
# koi_fwm_srao         9109 non-null float64
# koi_fwm_sdeco        9109 non-null float64
# koi_fwm_prao         8734 non-null float64
# koi_fwm_pdeco        8747 non-null float64
# koi_dicco_mra        8965 non-null float64
# koi_dicco_mdec       8965 non-null float64
# koi_dicco_msky       8965 non-null float64
# koi_dikco_mra        8994 non-null float64
# koi_dikco_mdec       8994 non-null float64
# koi_dikco_msky       8994 non-null float64
# dtypes: float64(60), int64(7), object(16)
# memory usage: 6.1+ MB

# %% [markdown]
# #### Drop Features
# Features with the following characteristics will be dropped from the dataset:
# - all NULL or Zeroes
# - categorial features which offer no predictive ability
# - inject leakage

# %%
#Drop Columns with all zeroes
cumulativeOOI = cumulativeOOI.drop(['koi_longp', 'koi_ingress', 'koi_model_dof', 'koi_model_chisq', 'koi_sage'], axis=1)

# %%
#Drop attributes with no predictive capability
cumulativeOOI = cumulativeOOI.drop(['rowid', 'kepoi_name', 'koi_comment', 'koi_limbdark_mod', 'koi_parm_prov', 'koi_trans_mod', 'koi_datalink_dvr', 'koi_datalink_dvs'], axis=1)

# %%
#Drop Columns which inject Leakage
cumulativeOOI = cumulativeOOI.drop(['koi_pdisposition', 'kepler_name', 'koi_score'], axis=1)

# %%
#Drop other categorical columns for first pass modeling
cumulativeOOI = cumulativeOOI.drop(['koi_tce_delivname', 'koi_sparprov'], axis=1)

# %% [markdown]
# ### Uniqueness
# The uniques of each column will be examined as well.  Columns with low or zero variance will be removed from the dataset.

# %%
df = cumulativeOOI.nunique(dropna = False)
print(df)
# Out:
# kepid               8214
# koi_disposition        3
# koi_vet_stat           1
# koi_vet_date           1
# koi_fpflag_nt          3
# koi_fpflag_ss          2
# koi_fpflag_co          2
# koi_fpflag_ec          2
# koi_disp_prov          1
# koi_period          9564
# koi_time0bk         9538
# koi_time0           7445
# koi_eccen              2
# koi_impact          2407
# koi_duration        7834
# koi_depth           2854
# koi_ror             8503
# koi_srho            9003
# koi_fittype            4
# koi_prad            2989
# koi_sma             3797
# koi_incl            2261
# koi_teq             2512
# koi_insol           7802
# koi_dor             6211
# koi_ldm_coeff4         2
# koi_ldm_coeff3         2
# koi_ldm_coeff2      1081
# koi_ldm_coeff1      1323
# koi_max_sngle_ev    8422
# koi_max_mult_ev     8423
# koi_model_snr       2741
# koi_count              7
# koi_num_transits    1628
# koi_tce_plnt_num       9
# koi_quarters         118
# koi_bin_oedp_sig    4876
# koi_steff           2446
# koi_slogg           1558
# koi_smet             120
# koi_srad            2290
# koi_smass           1477
# ra                  8131
# dec                 8195
# koi_kepmag          3888
# koi_gmag            4179
# koi_rmag            3918
# koi_imag            3744
# koi_zmag            3556
# koi_jmag            3744
# koi_hmag            3737
# koi_kmag            3729
# koi_fwm_stat_sig     930
# koi_fwm_sra         9031
# koi_fwm_sdec        9030
# koi_fwm_srao        2995
# koi_fwm_sdeco       2998
# koi_fwm_prao        1823
# koi_fwm_pdeco       1758
# koi_dicco_mra       1987
# koi_dicco_mdec      2010
# koi_dicco_msky      1736
# koi_dikco_mra       2075
# koi_dikco_mdec      2198
# koi_dikco_msky      1845
# dtype: int64

# %%
#Drop Columns with zero or near zero variance
cumulativeOOI = cumulativeOOI.drop(['koi_vet_stat', 'koi_vet_date', 'koi_disp_prov', 'koi_ldm_coeff3', 'koi_ldm_coeff4'], axis=1)

# %%
#cumulativeOOI.koi_ldm_coeff4.unique()

# %% [markdown]
# #### One Hot Encoding of koi_fittype

# %%
#Creating Dummy variables for categorical variable 'Primary' positions
#df2 = pd.get_dummies(df.Primary,prefix='Prim', prefix_sep='_')
#df = df.join(df2, how='inner')
#df.drop(['Primary'], axis=1, inplace=True)
fittypeEncode = pd.get_dummies(cumulativeOOI.koi_fittype, prefix="ENC", prefix_sep="_")
cumulativeOOI = cumulativeOOI.join(fittypeEncode, how='inner')
cumulativeOOI.drop(['koi_fittype'], axis=1, inplace=True)

# %% [markdown]
# #### Label Substitution for koi_disposition
# - False Positive = 0
# - Confirmed = 1
# - Candidate = 2

# %%
print(np.unique(cumulativeOOI.koi_disposition))
# Out:
# ['CANDIDATE' 'CONFIRMED' 'FALSE POSITIVE']

# %%
l = 'koi_disposition'

label = 2
counter = 0
tmpArray = np.unique(cumulativeOOI[l])
    
for t in tmpArray:
    print(l, tmpArray[label], counter)
    cumulativeOOI[l] = np.where(cumulativeOOI[l] == tmpArray[label], counter, cumulativeOOI[l])
    counter += 1
    label -= 1
# Out:
# koi_disposition FALSE POSITIVE 0
# koi_disposition CONFIRMED 1
# koi_disposition CANDIDATE 2

# %% [markdown]
# ### Missing Values

# %% [markdown]
# #### Missing Values Function
# Most machine learning algorithms do not accomodate to missing values.  The amount and degree of missingness is assesed below.

# %%
def rptMissingValues(df):
    try:
        del df2
    except:
        pass
    
    df2 = df.isnull().sum()
    df2 = df2[df2 > 0]
    df2 = pd.DataFrame({
        'n Missing' : df2,
        '% Missing' : ((df2 / df.shape[0])*100).round(2)})

    cm = sns.light_palette("red", as_cmap=True)
    df2.style.background_gradient(cmap=cm)
    return df2.style.background_gradient(cmap=cm);

# %%
mv = rptMissingValues(cumulativeOOI)
mv
# Out:
# <style  type="text/css" >
#     #T_f932000c_e2d7_11e8_b0e9_42010a800002row0_col0 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row0_col1 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row1_col0 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row1_col1 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row2_col0 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row2_col1 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row3_col0 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row3_col1 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row4_col0 {
#             background-color:  #ffb5b5;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row4_col1 {
#             background-color:  #ffb5b5;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row5_col0 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row5_col1 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row6_col0 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row6_col1 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row7_col0 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row7_col1 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row8_col0 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row8_col1 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row9_col0 {
#             background-color:  #ffb5b5;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row9_col1 {
#             background-color:  #ffb5b5;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row10_col0 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row10_col1 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row11_col0 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row11_col1 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row12_col0 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row12_col1 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row13_col0 {
#             background-color:  #ff3838;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row13_col1 {
#             background-color:  #ff3838;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row14_col0 {
#             background-color:  #ff3838;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row14_col1 {
#             background-color:  #ff3838;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row15_col0 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row15_col1 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row16_col0 {
#             background-color:  #ff3838;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row16_col1 {
#             background-color:  #ff3838;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row17_col0 {
#             background-color:  #ffb1b1;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row17_col1 {
#             background-color:  #ffb1b1;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row18_col0 {
#             background-color:  #ff3838;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row18_col1 {
#             background-color:  #ff3838;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row19_col0 {
#             background-color:  #ff0000;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row19_col1 {
#             background-color:  #ff0000;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row20_col0 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row20_col1 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row21_col0 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row21_col1 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row22_col0 {
#             background-color:  #ffabab;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row22_col1 {
#             background-color:  #ffabab;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row23_col0 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row23_col1 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row24_col0 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row24_col1 {
#             background-color:  #ffafaf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row25_col0 {
#             background-color:  #ffe5e5;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row25_col1 {
#             background-color:  #ffe5e5;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row26_col0 {
#             background-color:  #ffe0e0;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row26_col1 {
#             background-color:  #ffe0e0;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row27_col0 {
#             background-color:  #ffe5e5;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row27_col1 {
#             background-color:  #ffe5e5;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row28_col0 {
#             background-color:  #ffcfcf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row28_col1 {
#             background-color:  #ffcfcf;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row29_col0 {
#             background-color:  #ff8989;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row29_col1 {
#             background-color:  #ff8989;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row30_col0 {
#             background-color:  #ffe2e2;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row30_col1 {
#             background-color:  #ffe2e2;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row31_col0 {
#             background-color:  #ffe2e2;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row31_col1 {
#             background-color:  #ffe2e2;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row32_col0 {
#             background-color:  #ffe2e2;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row32_col1 {
#             background-color:  #ffe2e2;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row33_col0 {
#             background-color:  #ff4242;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row33_col1 {
#             background-color:  #ff4242;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row34_col0 {
#             background-color:  #ff9999;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row34_col1 {
#             background-color:  #ff9999;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row35_col0 {
#             background-color:  #ff9999;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row35_col1 {
#             background-color:  #ff9999;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row36_col0 {
#             background-color:  #ffa0a0;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row36_col1 {
#             background-color:  #ffa0a0;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row37_col0 {
#             background-color:  #ffa0a0;
#         }    #T_f932000c_e2d7_11e8_b0e9_42010a800002row37_col1 {
#             background-color:  #ffa0a0;
#         }    #T_f932000

# %% [markdown]
# #### Fill Missing Values with Zeroes
# One simple approach to solving for missing values is to fill all NULLs with zero.  If the missing values are valid missing values, this could be a good approach to solve for this issue.  However, filling all NULLs with zero could have adverse impacts when classifying data which is not part of the training dataset.

# %%
cumulativeFill = cumulativeOOI.fillna(value=0)

mv2 = rptMissingValues(cumulativeFill)
mv2
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_fc59841c_e2d7_11e8_b0e9_42010a800002" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >% Missing</th>
#         <th class="col_heading level0 col1" >n Missing</th>
#     </tr></thead>
# <tbody></tbody>
# </table>

# %% [markdown]
# Kepler object of interest 2306756 has several missing values.  It will be spot checked to verify missing values where correctly filled.

# %%
cumulativeFill[cumulativeFill.kepid == 2306756]
# Out:
#       kepid  koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 24  2306756                0              0              1              0
#
#     koi_fpflag_ec  koi_period  koi_time0bk    koi_time0  koi_eccen  \
# 24              0  386.603053   166.342079  2454999.342        0.0
#
#     koi_impact  koi_duration  koi_depth   koi_ror  koi_srho  koi_prad  \
# 24      0.9765        6.8057    24900.0  0.240528   4.63335      41.5
#
#     koi_sma  koi_incl  koi_teq  koi_insol  koi_dor  koi_ldm_coeff2  \
# 24   1.0719     89.95    297.0       1.84    332.0          0.2251
#
#     koi_ldm_coeff1  koi_max_sngle_ev  koi_max_mult_ev  koi_model_snr  \
# 24          0.4707               0.0              0.0          994.0
#
#     koi_count  koi_num_transits  koi_tce_plnt_num  koi_quarters  \
# 24          1               0.0               1.0           0.0
#
#     koi_bin_oedp_sig  koi_steff  koi_slogg  koi_smet  koi_srad  koi_smass  \
# 24               0.0     5543.0      4.081      0.44      1.58      1.103
#
#            ra        dec  koi_kepmag  koi_gmag  koi_rmag  koi_imag  koi_zmag  \
# 24  292.27374  37.671558      12.394    12.933    12.322    12.163    12.094
#
#     koi_jmag  koi_hmag  koi_kmag  koi_fwm_stat_sig  koi_fwm_sra  koi_fwm_sdec  \
# 24    11.151    10.808     10.72             0.002    19.484915     37.671579
#
#     koi_fwm_srao  koi_fwm_sdeco  koi_fwm_prao  koi_fwm_pdeco  koi_dicco_mra  \
# 24        -0.008          0.067       -0.0007         0.0006          0.001
#
#     koi_dicco_mdec  koi_dicco_msky  koi_dikco_mra  koi_dikco_mdec  \
# 24           0.037           0.037          0.001           0.163
#
#     koi_dikco_msky  ENC_LS  ENC_LS+MCMC  ENC_MCMC  ENC_none
# 24           0.163       0            0         1         0

# %%
cumulativeOOI[cumulativeOOI.kepid == 2306756]
# Out:
#       kepid koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 24  2306756               0              0              1              0
#
#     koi_fpflag_ec  koi_period  koi_time0bk    koi_time0  koi_eccen  \
# 24              0  386.603053   166.342079  2454999.342        0.0
#
#     koi_impact  koi_duration  koi_depth   koi_ror  koi_srho  koi_prad  \
# 24      0.9765        6.8057    24900.0  0.240528   4.63335      41.5
#
#     koi_sma  koi_incl  koi_teq  koi_insol  koi_dor  koi_ldm_coeff2  \
# 24   1.0719     89.95    297.0       1.84    332.0          0.2251
#
#     koi_ldm_coeff1  koi_max_sngle_ev  koi_max_mult_ev  koi_model_snr  \
# 24          0.4707               NaN              NaN          994.0
#
#     koi_count  koi_num_transits  koi_tce_plnt_num  koi_quarters  \
# 24          1               NaN               1.0           NaN
#
#     koi_bin_oedp_sig  koi_steff  koi_slogg  koi_smet  koi_srad  koi_smass  \
# 24               NaN     5543.0      4.081      0.44      1.58      1.103
#
#            ra        dec  koi_kepmag  koi_gmag  koi_rmag  koi_imag  koi_zmag  \
# 24  292.27374  37.671558      12.394    12.933    12.322    12.163    12.094
#
#     koi_jmag  koi_hmag  koi_kmag  koi_fwm_stat_sig  koi_fwm_sra  koi_fwm_sdec  \
# 24    11.151    10.808     10.72             0.002    19.484915     37.671579
#
#     koi_fwm_srao  koi_fwm_sdeco  koi_fwm_prao  koi_fwm_pdeco  koi_dicco_mra  \
# 24        -0.008          0.067       -0.0007         0.0006          0.001
#
#     koi_dicco_mdec  koi_dicco_msky  koi_dikco_mra  koi_dikco_mdec  \
# 24           0.037           0.037          0.001           0.163
#
#     koi_dikco_msky  ENC_LS  ENC_LS+MCMC  ENC_MCMC  ENC_none
# 24           0.163       0            0         1         0

# %% [markdown]
# #### Fill Missing Values Using Multiple Imputation
# Multiple imputation is an advanced technique to deal with missingness in datasets.  Multiple Imputation techniques seek to fill missing values with a value that preserves the natural variance of the dataset.  This can be advantageous as it minimizes bias when imputing data.  In this case, the fancyimpute package will utilize the K-nearest-neighbors algorithm to algorithmically fill missing values.

# %%
from fancyimpute import KNN as fiKNN

dfCols = cumulativeOOI.columns
cumulativeMice = pd.DataFrame(fiKNN(k=83).complete(cumulativeOOI))
cumulativeMice.columns = dfCols
# Out:
# Imputing row 1/9564 with 0 missing, elapsed time: 41.149
# Imputing row 101/9564 with 0 missing, elapsed time: 41.172
# Imputing row 201/9564 with 2 missing, elapsed time: 41.174
# Imputing row 301/9564 with 0 missing, elapsed time: 41.176
# Imputing row 401/9564 with 0 missing, elapsed time: 41.188
# Imputing row 501/9564 with 0 missing, elapsed time: 41.200
# Imputing row 601/9564 with 0 missing, elapsed time: 41.212
# Imputing row 701/9564 with 0 missing, elapsed time: 41.217
# Imputing row 801/9564 with 0 missing, elapsed time: 41.224
# Imputing row 901/9564 with 0 missing, elapsed time: 41.233
# Imputing row 1001/9564 with 0 missing, elapsed time: 41.245
# Imputing row 1101/9564 with 0 missing, elapsed time: 41.249
# Imputing row 1201/9564 with 0 missing, elapsed time: 41.253
# Imputing row 1301/9564 with 0 missing, elapsed time: 41.260
# Imputing row 1401/9564 with 0 missing, elapsed time: 41.262
# Imputing row 1501/9564 with 0 missing, elapsed time: 41.266
# Imputing row 1601/9564 with 1 missing, elapsed time: 41.271
# Imputing row 1701/9564 with 0 missing, elapsed time: 41.275
# Imputing row 1801/9564 with 0 missing, elapsed time: 41.279
# Imputing row 1901/9564 with 2 missing, elapsed time: 41.286
# Imputing row 2001/9564 with 38 missing, elapsed time: 41.297
# Imputing row 2101/9564 with 2 missing, elapsed time: 41.303
# Imputing row 2201/9564 with 0 missing, elapsed time: 41.309
# Imputing row 2301/9564 with 0 missing, elapsed time: 41.314
# Imputing row 2401/9564 with 0 missing, elapsed time: 41.319
# Imputing row 2501/9564 with 0 missing, elapsed time: 41.322
# Imputing row 2601/9564 with 0 missing, elapsed time: 41.325
# Imputing row 2701/9564 with 0 missing, elapsed time: 41.332
# Imputing row 2801/9564 with 1 missing, elapsed time: 41.334
# Imputing row 2901/9564 with 2 missing, elapsed time: 41.336
# Imputing row 3001/9564 with 0 missing, elapsed time: 41.338
# Imputing row 3101/9564 with 0 missing, elapsed time: 41.344
# Imputing row 3201/9564 with 0 missing, elapsed time: 41.353
# Imputing row 3301/9564 with 0 missing, elapsed time: 41.356
# Imputing row 3401/9564 with 0 missing, elapsed time: 41.359
# Imputing row 3501/9564 with 0 missing, elapsed time: 41.361
# Imputing row 3601/9564 with 7 missing, elapsed time: 41.367
# Imputing row 3701/9564 with 0 missing, elapsed time: 41.383
# Imputing row 3801/9564 with 19 missing, elapsed time: 41.394
# Imputing row 3901/9564 with 0 missing, elapsed time: 41.422
# Imputing row 4001/9564 with 0 missing, elapsed time: 41.433
# Imputing row 4101/9564 with 19 missing, elapsed time: 41.455
# Imputing row 4201/9564 with 0 missing, elapsed time: 41.475
# Imputing row 4301/9564 with 2 missing, elapsed time: 41.490
# Imputing row 4401/9564 with 0 missing, elapsed time: 41.506
# Imputing row 4501/9564 with 0 missing, elapsed time: 41.516
# Imputing row 4601/9564 with 0 missing, elapsed time: 41.532
# Imputing row 4701/9564 with 0 missing, elapsed time: 41.553
# Imputing row 4801/9564 with 0 missing, elapsed time: 41.562
# Imputing row 4901/9564 with 0 missing, elapsed time: 41.570
# Imputing row 5001/9564 with 0 missing, elapsed time: 41.574
# Imputing row 5101/9564 with 0 missing, elapsed time: 41.580
# Imputing row 5201/9564 with 0 missing, elapsed time: 41.588
# Imputing row 5301/9564 with 7 missing, elapsed time: 41.595
# Imputing row 5401/9564 with 6 missing, elapsed time: 41.604
# Imputing row 5501/9564 with 0 missing, elapsed time: 41.618
# Imputing row 5601/9564 with 19 missing, elapsed time: 41.637
# Imputing row 5701/9564 with 0 missing, elapsed time: 41.644
# Imputing row 5801/9564 with 2 missing, elapsed time: 41.677
# Imputing row 5901/9564 with 0 missing, elapsed time: 41.721
# Imputing row 6001/9564 with 0 missing, elapsed time: 41.746
# Imputing row 6101/9564 with 5 missing, elapsed time: 41.775
# Imputing row 6201/9564 with 5 missing, elapsed time: 41.806
# Imputing row 6301/9564 with 0 missing, elapsed time: 41.837
# Imputing row 6401/9564 with 0 missing, elapsed time: 41.874
# Imputing row 6501/9564 with 11 missing, elapsed time: 41.912
# Imputing row 6601/9564 with 1 missing, elapsed time: 41.948
# Imputing row 6701/9564 with 5 missing, elapsed time: 41.983
# Imputing row 6801/9564 with 0 missing, elapsed time: 42.017
# Imputing row 6901/9564 with 5 missing, elapsed time: 42.051
# Imputing row 7001/9564 with 0 missing, elapsed time: 42.068
# Imputing row 7101/9564 with 1 missing, elapsed time: 42.087
# Imputing row 7201/9564 with 24 missing, elapsed time: 42.108
# Imputing row 7301/9564 with 19 missing, elapsed time: 42.134
# Imputing row 7401/9564 with 0 missing, elapsed time: 42.158
# Imputing row 7501/9564 with 1 missing, elapsed time: 42.168
# Imputing row 7601/9564 with 0 missing, elapsed time: 42.178
# Imputing row 7701/9564 with 0 missing, elapsed time: 42.191
# Imputing row 7801/9564 with 0 missing, elapsed time: 42.199
# Imputing row 7901/9564 with 0 missing, elapsed time: 42.208
# Imputing row 8001/9564 with 0 missing, elapsed time: 42.217
# Imputing row 8101/9564 with 7 missing, elapsed time: 42.226
# Imputing row 8201/9564 with 0 missing, elapsed time: 42.234
# Imputing row 8301/9564 with 1 missing, elapsed time: 42.247
# Imputing row 8401/9564 with 0 missing, elapsed time: 42.253
# Imputing row 8501/9564 with 0 missing, elapsed time: 42.260
# Imputing row 8601/9564 with 4 missing, elapsed time: 42.266
# Imputing row 8701/9564 with 0 missing, elapsed time: 42.273
# Imputing row 8801/9564 with 0 missing, elapsed time: 42.280
# Imputing row 8901/9564 with 1 missing, elapsed time: 42.287
# Imputing row 9001/9564 with 0 missing, elapsed time: 42.292
# Imputing row 9101/9564 with 0 missing, elapsed time: 42.295
# Imputing row 9201/9564 with 0 missing, elapsed time: 42.299
# Imputing row 9301/9564 with 0 missing, elapsed time: 42.304
# Imputing row 9401/9564 with 0 missing, elapsed time: 42.307
# Imputing row 9501/9564 with 0 missing, elapsed time: 42.312

# %% [markdown]
# No missing values exist after multiple imputation.

# %%
mv3 = rptMissingValues(cumulativeMice)
mv3
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_2369869c_e2d8_11e8_b0e9_42010a800002" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >% Missing</th>
#         <th class="col_heading level0 col1" >n Missing</th>
#     </tr></thead>
# <tbody></tbody>
# </table>

# %% [markdown]
# Spot check object of interest 2306756 to verify all missing values have been filled.

# %%
cumulativeMice[cumulativeMice.kepid == 2306756]
# Out:
#         kepid  koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 24  2306756.0              0.0            0.0            1.0            0.0
#
#     koi_fpflag_ec  koi_period  koi_time0bk    koi_time0  koi_eccen  \
# 24            0.0  386.603053   166.342079  2454999.342        0.0
#
#     koi_impact  koi_duration  koi_depth   koi_ror  koi_srho  koi_prad  \
# 24      0.9765        6.8057    24900.0  0.240528   4.63335      41.5
#
#     koi_sma  koi_incl  koi_teq  koi_insol  koi_dor  koi_ldm_coeff2  \
# 24   1.0719     89.95    297.0       1.84    332.0          0.2251
#
#     koi_ldm_coeff1  koi_max_sngle_ev  koi_max_mult_ev  koi_model_snr  \
# 24          0.4707         27.065371       132.087117          994.0
#
#     koi_count  koi_num_transits  koi_tce_plnt_num  koi_quarters  \
# 24        1.0        384.611062               1.0  9.508400e+30
#
#     koi_bin_oedp_sig  koi_steff  koi_slogg  koi_smet  koi_srad  koi_smass  \
# 24          0.477568     5543.0      4.081      0.44      1.58      1.103
#
#            ra        dec  koi_kepmag  koi_gmag  koi_rmag  koi_imag  koi_zmag  \
# 24  292.27374  37.671558      12.394    12.933    12.322    12.163    12.094
#
#     koi_jmag  koi_hmag  koi_kmag  koi_fwm_stat_sig  koi_fwm_sra  koi_fwm_sdec  \
# 24    11.151    10.808     10.72             0.002    19.484915     37.671579
#
#     koi_fwm_srao  koi_fwm_sdeco  koi_fwm_prao  koi_fwm_pdeco  koi_dicco_mra  \
# 24        -0.008          0.067       -0.0007         0.0006          0.001
#
#     koi_dicco_mdec  koi_dicco_msky  koi_dikco_mra  koi_dikco_mdec  \
# 24           0.037           0.037          0.001           0.163
#
#     koi_dikco_msky  ENC_LS  ENC_LS+MCMC  ENC_MCMC  ENC_none
# 24           0.163     0.0          0.0       1.0       0.0

# %% [markdown]
# ### Create Test and Train Data Sets

# %% [markdown]
# Test and Train data sets are created to facilitate model development and predictions.  The models will be built using the training data sets.  The training data set contains all objects of interest which have already been classified by NASA.  This will allow for the machine learning model to be tuned using known outcomes.  All objects of interest with a koi_disposition of "CANDIDATE" have not yet been confirmed as being an exoplanet.  These observations will become the test dataset where a probability of being a exoplanet will be assigned using the model built using the train data set.

# %%
#Create Test and Train Data Sets

##cumulativeOOI
exoTest = cumulativeOOI[cumulativeOOI.koi_disposition == 2]
exoTrain = cumulativeOOI[cumulativeOOI.koi_disposition != 2]

##cumulativeFill
exoTestFill = cumulativeFill[cumulativeFill.koi_disposition == 2]
exoTrainFill = cumulativeFill[cumulativeFill.koi_disposition != 2]

##cumulativeMice
exoTestMice = cumulativeMice[cumulativeMice.koi_disposition == 2]
exoTrainMice = cumulativeMice[cumulativeMice.koi_disposition != 2]

# %% [markdown]
# Verify the shape of test and train datasets to assure the expected number of records and columns exist in each.

# %%
print("exoTest Shape", exoTest.shape)
print("exoTrain Shape", exoTrain.shape)

print("exoTestFill Shape", exoTestFill.shape)
print("exoTrainFill Shape", exoTrainFill.shape)

print("exoTestMice Shape", exoTestMice.shape)
print("exoTrainMice Shape", exoTrainMice.shape)
# Out:
# exoTest Shape (2426, 63)
# exoTrain Shape (7138, 63)
# exoTestFill Shape (2426, 63)
# exoTrainFill Shape (7138, 63)
# exoTestMice Shape (2426, 63)
# exoTrainMice Shape (7138, 63)

# %% [markdown]
# Split the response (y) and explantory (X) features in preparation of model training.  Save the kepler ID for the test and train datasets for future use.  The disposition and kepler ID will then be dropped as these inject leakage into the model.

# %%
#Split X, y / explantory, reponse variables

#save kepid
exoTestX_kepid = exoTest.kepid
exoTrainX_kepid = exoTrain.kepid

##cumulativeOOI
exoTestY = exoTest.koi_disposition
exoTestX = exoTest.drop(['koi_disposition', 'kepid'], axis=1)
exoTrainY = exoTrain.koi_disposition
exoTrainX = exoTrain.drop(['koi_disposition', 'kepid'], axis=1)

svCols = exoTrainX.columns

##cumulativeFill
exoTestFillY = exoTestFill.koi_disposition
exoTestFillX = exoTestFill.drop(['koi_disposition', 'kepid'], axis=1)
exoTrainFillY = exoTrainFill.koi_disposition
exoTrainFillX = exoTrainFill.drop(['koi_disposition', 'kepid'], axis=1)

##cumulativeMice
exoTestMiceY = exoTestMice.koi_disposition
exoTestMiceX = exoTestMice.drop(['koi_disposition', 'kepid'], axis=1)
exoTrainMiceY = exoTrainMice.koi_disposition
exoTrainMiceX = exoTrainMice.drop(['koi_disposition', 'kepid'], axis=1)

# %%
len(svCols)
# Out:
# 61

# %% [markdown]
# Scale the data.

# %%
from sklearn.preprocessing import StandardScaler

# %%
#Scale Data
scaler = StandardScaler()
scaledTestFillX = scaler.fit_transform(exoTestFillX)
scaledTrainFillX = scaler.fit_transform(exoTrainFillX)
scaledTestMiceX = scaler.fit_transform(exoTestMiceX)
scaledTrainMiceX = scaler.fit_transform(exoTrainMiceX)

# %% [markdown]
# Convert the scaled data back to dataframes with the correct column headers.

# %%
#Convert scaled objects to dataframes
df_scaledTestFillX = pd.DataFrame(scaledTestFillX, columns=svCols)
df_scaledTrainFillX = pd.DataFrame(scaledTrainFillX, columns=svCols)
df_scaledTestMiceX = pd.DataFrame(scaledTestMiceX, columns=svCols)
df_scaledTrainMiceX = pd.DataFrame(scaledTrainMiceX, columns=svCols)

# %% [markdown]
# Save the scaled dataframes to pickle files for future use.  This also allows us the ability to skip the data cleansing portion of the program if necessary.

# %%
#Save to pickle files
exoTrainX.to_pickle('./pkl/exoTrainX.pkl')
exoTestX.to_pickle('./pkl/exoTestX.pkl')

##Zero Filled DataFrames
df_scaledTestFillX.to_pickle('./pkl/df_scaledTestFillX.pkl')
df_scaledTrainFillX.to_pickle('./pkl/df_scaledTrainFillX.pkl')
exoTestFillX.to_pickle('./pkl/exoTestFillX.pkl')
exoTrainFillX.to_pickle('./pkl/exoTrainFillX.pkl')

##MICE filled Dataframes
df_scaledTestMiceX.to_pickle('./pkl/df_scaledTestMiceX.pkl')
df_scaledTrainMiceX.to_pickle('./pkl/df_scaledTrainMiceX.pkl')
exoTestMiceX.to_pickle('./pkl/exoTestMiceX.pkl')
exoTrainMiceX.to_pickle('./pkl/exoTrainMiceX.pkl')

#Write kepler IDs to pickle files
exoTestX_kepid.to_pickle('./pkl/exoTestX_kepid.pkl')
exoTrainX_kepid.to_pickle('./pkl/exoTrainX_kepid.pkl')

#Write response variables to pickle files
exoTestFillY.to_pickle('./pkl/exoTestFillY.pkl')
exoTrainFillY.to_pickle('./pkl/exoTrainFillY.pkl')
exoTestMiceY.to_pickle('./pkl/exoTestMiceY.pkl')
exoTrainMiceY.to_pickle('./pkl/exoTrainMiceY.pkl')
exoTestY.to_pickle('./pkl/exoTestY.pkl')
exoTrainY.to_pickle('./pkl/exoTrainY.pkl')

# %% [markdown]
# Spot check the scaled dataframe.

# %%
df_scaledTrainMiceX.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0      -0.050642      -0.672744      -0.599898      -0.437782   -0.381155
# 1      -0.050642      -0.672744      -0.599898      -0.437782    0.013289
# 2      -0.050642       1.486450      -0.599898      -0.437782   -0.449202
# 3      -0.050642      -0.672744      -0.599898      -0.437782   -0.442278
# 4      -0.050642      -0.672744      -0.599898      -0.437782   -0.367053
#
#    koi_time0bk  koi_time0  koi_eccen  koi_impact  koi_duration  koi_depth  \
# 0     0.121114   0.121118        0.0   -0.191773     -0.410556  -0.327825
# 1    -0.004602  -0.004600        0.0   -0.055849     -0.188747  -0.325031
# 2     0.117493   0.117499        0.0    0.157306     -0.489444  -0.247302
# 3     0.137670   0.137677        0.0   -0.020323     -0.597079  -0.327965
# 4     0.131491   0.131489        0.0   -0.070677     -0.176222  -0.318072
#
#     koi_ror  koi_srho  koi_prad   koi_sma  koi_incl   koi_teq  koi_insol  \
# 0 -0.088493 -0.082259 -0.032953 -0.369817  0.528955 -0.417069  -0.053892
# 1 -0.086738 -0.085916 -0.032776  0.267632  0.523538 -0.801560  -0.054358
# 2  0.025717 -0.141542 -0.023270 -0.568405 -0.829372  0.244256  -0.049481
# 3 -0.087955 -0.106503 -0.032801 -0.532144  0.273178  0.256340  -0.049292
# 4 -0.083977 -0.132563 -0.032444 -0.322711  0.435671 -0.370930  -0.053774
#
#     koi_dor  koi_ldm_coeff2  koi_ldm_coeff1  koi_max_sngle_ev  \
# 0 -0.216185       -0.413408        0.524848         -0.246799
# 1  0.145585       -0.413408        0.524848         -0.244535
# 2 -0.362909        0.475996       -0.461441         -0.206197
# 3 -0.325622        0.443457       -0.362529         -0.247260
# 4 -0.273765        0.513184       -0.503831         -0.242119
#
#    koi_max_mult_ev  koi_model_snr  koi_count  koi_num_transits  \
# 0        -0.266899      -0.333146   0.664082         -0.497914
# 1        -0.268760      -0.344364   0.664082         -0.707206
# 2        -0.152599       0.193865  -0.452577          0.358929
# 3        -0.265848      -0.327425  -0.452577          0.169315
# 4        -0.260947      -0.298708   1.780740         -0.581989
#
#    koi_tce_plnt_num  koi_quarters  koi_bin_oedp_sig  koi_steff  koi_slogg  \
# 0         -0.355406      0.485948          0.581059  -0.334384   0.369605
# 1          1.246530      0.485948         -0.767106  -0.334384   0.369605
# 2         -0.355406      0.485948         -0.771639   0.091986   0.589480
# 3         -0.355406     -2.007459         -0.162688   0.367299   0.303869
# 4         -0.355406     -2.007461         -0.579494   0.385572   0.412673
#
#    koi_smet  koi_srad  koi_smass        ra       dec  koi_kepmag  koi_gmag  \
# 0  0.977938 -0.135324  -0.307612 -0.047347  1.236997    0.785766  0.712524
# 1  0.977938 -0.135324  -0.307612 -0.047347  1.236997    0.785766  0.712524
# 2 -1.365194 -0.156704  -0.540428 -1.393939  1.277212    0.962816  0.850083
# 3  0.729424 -0.116616   0.186070 -0.716338  1.260682    0.900494  0.794404
# 4  0.196894 -0.128250   0.068260  0.868369  1.260253    1.045675  0.937858
#
#    koi_rmag  koi_imag  koi_zmag  koi_jmag  koi_hmag  koi_kmag  \
# 0  0.762694  0.812208  0.861562  0.844909  0.891242  0.871882
# 1  0.762694  0.812208  0.861562  0.844909  0.891242  0.871882
# 2  0.964216  1.017147  1.075407  1.030458  1.015123  0.996578
# 3  0.903192  0.948324  1.054845  1.060875  1.133585  1.107332
# 4  1.051495  1.101264  1.219341  1.184067  1.171523  1.246744
#
#    koi_fwm_stat_sig  koi_fwm_sra  koi_fwm_sdec  koi_fwm_srao  koi_fwm_sdeco  \
# 0         -0.573011    -0.044485      1.237201      0.034609       0.047893
# 1         -0.568559    -0.044577      1.237223     -0.011659       0.060382
# 2         -0.581915    -1.400747      1.277345      0.010995       0.007496
# 3          2.681568    -0.718293      1.260831      0.015403       0.017315
# 4          0.077339     0.877728      1.260397      0.010602       0.013439
#
#    koi_fwm_prao  koi_fwm_pdeco  koi_dicco_mra  koi_dicco_mdec  koi_dicco_msky  \
# 0     -0.000725       0.002980       0.003041        0.088529       -0.586695
# 1      0.012621      -0.001874       0.157339        0.016723       -0.527572
# 2      0.049245      -0.005466      -0.089152        0.069500       -0.559000
# 3      0.003620       0.007639       0.018471       -0.015590       -0.617812
# 4      0.002999      -0.196622       0.022328       -0.008409       -0.624035
#
#    koi_dikco_mra  koi_dikco_mdec  koi_dikco_msky    ENC_LS  ENC_LS+MCMC  \
# 0       0.038529        0.142112       -0.542492 -0.104427     0.412742
# 1       0.196293        0.073679       -0.486625 -0.104427     0.412742
# 2      -0.091145        0.066115       -0.556148 -0.104427     0.412742
# 3       0.034682        0.037661       -0.620085 -0.104427     0.412742
# 4       0.000050        0.001643       -0.616981 -0.104427     0.412742
#
#    ENC_MCMC  ENC_none
# 0  -0.32948 -0.195588
# 1  -0.32948 -0.195588
# 2  -0.32948 -0.195588
# 3  -0.32948 -0.195588
# 4  -0.32948 -0.195588
